# %%
import os
import re
from pathlib import Path
from pypdf import PdfReader

def convert_pdfs_to_text():
    # Define paths with absolute path to ensure correct location
    pdf_dir = Path("../aptnote_download").absolute()
    output_base_dir = Path("./pypdf").absolute()
    
    print(f"Looking for PDF files in: {pdf_dir}")
    
    # Check if directory exists
    if not pdf_dir.exists():
        print(f"Error: Directory {pdf_dir} does not exist!")
        return
    
    # List all files in the directory to debug
    all_files = list(pdf_dir.glob("*"))
    print(f"Found {len(all_files)} files in directory")
    for file in all_files:
        print(f"  - {file}")
    
    # Filter PDF files - recursively search in all subdirectories
    pdf_files = list(pdf_dir.glob("**/*.pdf"))
    print(f"Found {len(pdf_files)} PDF files")
    
    if len(pdf_files) == 0:
        print("No PDF files found. Check the directory path and file extensions.")
        return
    
    # Process each PDF file
    total_files = len(pdf_files)
    print(f"Starting conversion of {total_files} PDF files...")
    
    successful_conversions = 0
    failed_conversions = 0
    
    for i, pdf_file in enumerate(pdf_files, 1):
        try:
            # Get the parent directory name (which should be the year)
            parent_dir = pdf_file.parent.name
            
            # If parent directory is a year (like 2023), use it
            # Otherwise try to extract year from filename using regex
            if re.match(r'^20\d{2}$', parent_dir):
                year = parent_dir
            else:
                year_match = re.search(r'(20\d{2})', pdf_file.name)
                year = year_match.group(1) if year_match else "unknown"
            
            # Create year directory if it doesn't exist
            year_dir = output_base_dir / year
            year_dir.mkdir(exist_ok=True)
            
            # Output text file path
            output_file = year_dir / f"{pdf_file.stem}.txt"
            
            print(f"[{i}/{total_files}] Converting {pdf_file.name} to {output_file}")
            
            # Extract text using PyPDF
            reader = PdfReader(pdf_file)
            text_content = ""
            
            for page in reader.pages:
                text_content += page.extract_text() + "\n"
            
            # Write text to output file
            with open(output_file, 'w', encoding='utf-8') as f:
                f.write(text_content)
                
            print(f"[{i}/{total_files}] Successfully converted {pdf_file.name}")
            successful_conversions += 1
            
        except Exception as e:
            print(f"[{i}/{total_files}] Error processing {pdf_file.name}: {str(e)}")
            failed_conversions += 1
    
    # Print summary
    print("\nConversion Summary:")
    print(f"Total PDF files: {total_files}")
    print(f"Successfully converted: {successful_conversions}")
    print(f"Failed conversions: {failed_conversions}")
    
    if successful_conversions > 0:
        print(f"\nText files have been saved to: {output_base_dir}")

if __name__ == "__main__":
    convert_pdfs_to_text()

# %%
import os
import re
from pathlib import Path
import fitz  # PyMuPDF

def convert_pdfs_to_text():
    # Define paths with absolute path to ensure correct location
    pdf_dir = Path("../aptnote_download").absolute()
    output_base_dir = Path("./pymupdf").absolute()
    
    print(f"Looking for PDF files in: {pdf_dir}")
    
    # Check if directory exists
    if not pdf_dir.exists():
        print(f"Error: Directory {pdf_dir} does not exist!")
        return
    
    # List all files in the directory to debug
    all_files = list(pdf_dir.glob("*"))
    print(f"Found {len(all_files)} files in directory")
    for file in all_files:
        print(f"  - {file}")
    
    # Filter PDF files - recursively search in all subdirectories
    pdf_files = list(pdf_dir.glob("**/*.pdf"))
    print(f"Found {len(pdf_files)} PDF files")
    
    if len(pdf_files) == 0:
        print("No PDF files found. Check the directory path and file extensions.")
        return
    
    # Process each PDF file
    total_files = len(pdf_files)
    print(f"Starting conversion of {total_files} PDF files...")
    
    successful_conversions = 0
    failed_conversions = 0
    
    for i, pdf_file in enumerate(pdf_files, 1):
        try:
            # Get the parent directory name (which should be the year)
            parent_dir = pdf_file.parent.name
            
            # If parent directory is a year (like 2023), use it
            # Otherwise try to extract year from filename using regex
            if re.match(r'^20\d{2}$', parent_dir):
                year = parent_dir
            else:
                year_match = re.search(r'(20\d{2})', pdf_file.name)
                year = year_match.group(1) if year_match else "unknown"
            
            # Create year directory if it doesn't exist
            year_dir = output_base_dir / year
            year_dir.mkdir(exist_ok=True)
            
            # Output text file path
            output_file = year_dir / f"{pdf_file.stem}.txt"
            
            print(f"[{i}/{total_files}] Converting {pdf_file.name} to {output_file}")
            
            # Extract text using PyMuPDF
            text_content = ""
            doc = fitz.open(pdf_file)
            
            for page_num in range(len(doc)):
                page = doc[page_num]
                text_content += page.get_text() + "\n"
            
            doc.close()
            
            # Write text to output file
            with open(output_file, 'w', encoding='utf-8') as f:
                f.write(text_content)
                
            print(f"[{i}/{total_files}] Successfully converted {pdf_file.name}")
            successful_conversions += 1
            
        except Exception as e:
            print(f"[{i}/{total_files}] Error processing {pdf_file.name}: {str(e)}")
            failed_conversions += 1
    
    # Print summary
    print("\nConversion Summary:")
    print(f"Total PDF files: {total_files}")
    print(f"Successfully converted: {successful_conversions}")
    print(f"Failed conversions: {failed_conversions}")
    
    if successful_conversions > 0:
        print(f"\nText files have been saved to: {output_base_dir}")

if __name__ == "__main__":
    convert_pdfs_to_text()
# Out:
# Looking for PDF files in: e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download
# Found 28 files in directory
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\.gitignore
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\2006
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\2008
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\2009
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\2010
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\2011
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\2012
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\2013
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\2014
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\2015
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\2016
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\2017
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\2018
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\2019
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\2020
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\2021
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\2022
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\2023
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\2024
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\APTnotes_async_download_python34.py
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\APTnotes_async_download_python35.py
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\APTnotes_async_requirements.txt
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\APTnotes_sync_download.py
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\APTnotes_sync_requirements.txt
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\README.md
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\utilities.py
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\__init__.py
#   - e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\..\aptnote_download\__pycache__
# Found 683 PDF files
# Starting conversion of 683 PDF files...
# [1/683] Converting WickedRose_andNCPH.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2006\WickedRose_andNCPH.txt
# [1/683] Successfully converted WickedRose_andNCPH.pdf
# [2/683] Converting 556_10535_798405_Annex87_CyberAttacks.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2008\556_10535_798405_Annex87_CyberAttacks.txt
# [2/683] Successfully converted 556_10535_798405_Annex87_CyberAttacks.pdf
# [3/683] Converting Fritz_HOW-CHINA-WILL-USE-CYBER-WARFARE(Oct-01-08).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2008\Fritz_HOW-CHINA-WILL-USE-CYBER-WARFARE(Oct-01-08).txt
# [3/683] Successfully converted Fritz_HOW-CHINA-WILL-USE-CYBER-WARFARE(Oct-01-08).pdf
# [4/683] Converting Ashmore_Impact-of-Alleged-Russian-Cyber-Attacks(Jan-18-09).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2009\Ashmore_Impact-of-Alleged-Russian-Cyber-Attacks(Jan-18-09).txt
# [4/683] Successfully converted Ashmore_Impact-of-Alleged-Russian-Cyber-Attacks(Jan-18-09).pdf
# [5/683] Converting ghostnet.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\
pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\Dark_Seoul_Cyberattack.txt
# [63/683] Successfully converted Dark_Seoul_Cyberattack.pdf
# [64/683] Converting dissecting-operation-troy.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\dissecting-operation-troy.txt
# [64/683] Successfully converted dissecting-operation-troy.pdf
# [65/683] Converting energy-at-risk.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\energy-at-risk.txt
# [65/683] Successfully converted energy-at-risk.pdf
# [66/683] Converting ETSO_APT_Attacks_Analysis.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\ETSO_APT_Attacks_Analysis.txt
# [66/683] Successfully converted ETSO_APT_Attacks_Analysis.pdf
# [67/683] Converting fireeye-china-chopper-report.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\fireeye-china-chopper-report.txt
# [67/683] Successfully converted fireeye-china-chopper-report.pdf
# [68/683] Converting fireeye-malware-supply-chain.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\fireeye-malware-supply-chain.txt
# [68/683] Successfully converted fireeye-malware-supply-chain.pdf
# [69/683] Converting fireeye-operation-ke3chang.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\fireeye-operation-ke3chang.txt
# [69/683] Successfully converted fireeye-operation-ke3chang.pdf
# [70/683] Converting fireeye-poison-ivy-report.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\fireeye-poison-ivy-report.txt
# [70/683] Successfully converted fireeye-poison-ivy-report.pdf
# [71/683] Converting FireEye-Terminator_RAT.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\FireEye-Terminator_RAT.txt
# [71/683] Successfully converted FireEye-Terminator_RAT.pdf
# [72/683] Converting fireeye-wwc-report.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\fireeye-wwc-report.txt
# [72/683] Successfully converted fireeye-wwc-report.pdf
# [73/683] Converting FireEye_Operation-Beebus(Feb-1-13).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\FireEye_Operation-Beebus(Feb-1-13).txt
# [73/683] Successfully converted FireEye_Operation-Beebus(Feb-1-13).pdf
# [74/683] Converting FireEye_The-Mutter-Backdoor-Operation-Beebus-with-New-Targets(Apr-17-13).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\FireEye_The-Mutter-Backdoor-Operation-Beebus-with-New-Targets(Apr-17-13).txt
# [74/683] Successfully converted FireEye_The-Mutter-Backdoor-Operation-Beebus-with-New-Targets(Apr-17-13).pdf
# [75/683] Converting FTA 1010 - njRAT The Saga Continues.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\FTA 1010 - njRAT The Saga Continues.txt
# [75/683] Successfully converted FTA 1010 - njRAT The Saga Continues.pdf
# [76/683] Converting fta-1009---njrat-uncovered-1.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\fta-1009---njrat-uncovered-1.txt
# [76/683] Successfully converted fta-1009---njrat-uncovered-1.pdf
# [77/683] Converting hidden_lynx.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\hidden_lynx.txt
# [77/683] Successfully converted hidden_lynx.pdf
# [78/683] Converting icefog.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\icefog.txt
# [78/683] Successfully converted icefog.pdf
# [79/683] Converting India_Pak_Tranchulas.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\India_Pak_Tranchulas.txt
# [79/683] Successfully converted India_Pak_Tranchulas.pdf
# [80/683] Converting Inside_Report_by_Infosec_Consortium.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\Inside_Report_by_Infosec_Consortium.txt
# [80/683] Successfully converted Inside_Report_by_Infosec_Consortium.pdf
# [81/683] Converting kaspersky-the-net-traveler-part1-final.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\kaspersky-the-net-traveler-part1-final.txt
# [81/683] Successfully converted kaspersky-the-net-traveler-part1-final.pdf
# [82/683] Converting KeyBoy_Vietnam_India.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\KeyBoy_Vietnam_India.txt
# [82/683] Successfully converted KeyBoy_Vietnam_India.pdf
# [83/683] Converting Kimsuky.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\
pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\stuxnet_0_5_the_missing_link.txt
# [102/683] Successfully converted stuxnet_0_5_the_missing_link.pdf
# [103/683] Converting Surtr_Malware_Tibetan.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\Surtr_Malware_Tibetan.txt
# [103/683] Successfully converted Surtr_Malware_Tibetan.pdf
# [104/683] Converting themysteryofthepdf0-dayassemblermicrobackdoor.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\themysteryofthepdf0-dayassemblermicrobackdoor.txt
# [104/683] Successfully converted themysteryofthepdf0-dayassemblermicrobackdoor.pdf
# [105/683] Converting theteamspystory_final_t2.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\theteamspystory_final_t2.txt
# [105/683] Successfully converted theteamspystory_final_t2.pdf
# [106/683] Converting tr-12-circl-plugx-analysis-v1.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\tr-12-circl-plugx-analysis-v1.txt
# [106/683] Successfully converted tr-12-circl-plugx-analysis-v1.pdf
# [107/683] Converting Trojan.APT.BaneChant.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\Trojan.APT.BaneChant.txt
# [107/683] Successfully converted Trojan.APT.BaneChant.pdf
# [108/683] Converting Trojan.APT.Seinup.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\Trojan.APT.Seinup.txt
# [108/683] Successfully converted Trojan.APT.Seinup.pdf
# [109/683] Converting Unveiling an Indian Cyberattack Infrastructure - appendixes.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\Unveiling an Indian Cyberattack Infrastructure - appendixes.txt
# [109/683] Successfully converted Unveiling an Indian Cyberattack Infrastructure - appendixes.pdf
# [110/683] Converting US-13-Yarochkin-In-Depth-Analysis-of-Escalated-APT-Attacks-Slides.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\US-13-Yarochkin-In-Depth-Analysis-of-Escalated-APT-Attacks-Slides.txt
# [110/683] Successfully converted US-13-Yarochkin-In-Depth-Analysis-of-Escalated-APT-Attacks-Slides.pdf
# [111/683] Converting winnti-more-than-just-a-game-130410.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\winnti-more-than-just-a-game-130410.txt
# [111/683] Successfully converted winnti-more-than-just-a-game-130410.pdf
# [112/683] Converting wp-fakem-rat.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2013\wp-fakem-rat.txt
# [112/683] Successfully converted wp-fakem-rat.pdf
# [113/683] Converting Aided_Frame_Aided_Direction.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Aided_Frame_Aided_Direction.txt
# [113/683] Successfully converted Aided_Frame_Aided_Direction.pdf
# [114/683] Converting Alienvault_Scanbox.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Alienvault_Scanbox.txt
# [114/683] Successfully converted Alienvault_Scanbox.pdf
# [115/683] Converting Anunak_APT_against_financial_institutions.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Anunak_APT_against_financial_institutions.txt
# [115/683] Successfully converted Anunak_APT_against_financial_institutions.pdf
# [116/683] Converting apt28.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\apt28.txt
# [116/683] Successfully converted apt28.pdf
# [117/683] Converting ASERT-Threat-Intelligence-Brief-2014-07-Illuminating-Etumbot-APT.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\ASERT-Threat-Intelligence-Brief-2014-07-Illuminating-Etumbot-APT.txt
# [117/683] Successfully converted ASERT-Threat-Intelligence-Brief-2014-07-Illuminating-Etumbot-APT.pdf
# [118/683] Converting bcs_wp_InceptionReport_EN_v12914.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\bcs_wp_InceptionReport_EN_v12914.txt
# [118/683] Successfully converted bcs_wp_InceptionReport_EN_v12914.pdf
# [119/683] Converting BlackEnergy2_Plugins_Router.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\BlackEnergy2_Plugins_Router.txt
# [119/683] Successfully converted BlackEnergy2_Plugins_Router.pdf
# [120/683] Converting blackenergy_whitepaper.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\blackenergy_whitepaper.txt
# [120/683] Successfully converted blackenergy_whitepaper.pdf
# [121/683] Converting Bluecoat_SnakeInTheGrass-Python-Malware-Targeted(06-10-2014).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Bluecoat_SnakeInTheGrass-Python-Malware-Targeted(06-10-2014).txt
# [121/683] Successfully converted Bluecoat_SnakeInTheGrass-Python-Malware-Targeted(06-10-2014).pdf
# [122/683] Converting Chinese_MITM_Google.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Chinese_MITM_Google.txt
# [122/683] Successfully converted Chinese_MITM_Google.pdf
# [123/683] Converting circl-tr25-analysis-turla-pfinet-snake-uroburos.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\circl-tr25-analysis-turla-pfinet-snake-uroburos.txt
# [123/683] Successfully converted circl-tr25-analysis-turla-pfinet-snake-uroburos.pdf
# [124/683] Converting CloudAtlas_RedOctober_APT.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\CloudAtlas_RedOctober_APT.txt
# [124/683] Successfully converted CloudAtlas_RedOctober_APT.pdf
# [125/683] Converting Compromise_Greece_Beijing.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Compromise_Greece_Beijing.txt
# [125/683] Successfully converted Compromise_Greece_Beijing.pdf
# [126/683] Converting cosmicduke_whitepaper.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\cosmicduke_whitepaper.txt
# [126/683] Successfully converted cosmicduke_whitepaper.pdf
# [127/683] Converting CrowdStrike_Flying_Kitten.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\CrowdStrike_Flying_Kitten.txt
# [127/683] Successfully converted CrowdStrike_Flying_Kitten.pdf
# [128/683] Converting Crowdstrike_The French Connection(Feb-25-14).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Crowdstrike_The French Connection(Feb-25-14).txt
# [128/683] Successfully converted Crowdstrike_The French Connection(Feb-25-14).pdf
# [129/683] Converting darkhotelappendixindicators_kl.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\darkhotelappendixindicators_kl.txt
# [129/683] Successfully converted darkhotelappendixindicators_kl.pdf
# [130/683] Converting darkhotel_kl_07.11.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\darkhotel_kl_07.11.txt
# [130/683] Successfully converted darkhotel_kl_07.11.pdf
# [131/683] Converting Darwin_fav_APT_Group.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Darwin_fav_APT_Group.txt
# [131/683] Successfully converted Darwin_fav_APT_Group.pdf
# [132/683] Converting deep-panda-webshells.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\deep-panda-webshells.txt
# [132/683] Successfully converted deep-panda-webshells.pdf
# [133/683] Converting DEEP_PANDA_Sakula.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\DEEP_PANDA_Sakula.txt
# [133/683] Successfully converted DEEP_PANDA_Sakula.pdf
# [134/683] Converting Democracy_HongKong_Under_Attack.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Democracy_HongKong_Under_Attack.txt
# [134/683] Successfully converted Democracy_HongKong_Under_Attack.pdf
# [135/683] Converting Derusbi_Server_Analysis-Final.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Derusbi_Server_Analysis-Final.txt
# [135/683] Successfully converted Derusbi_Server_Analysis-Final.pdf
# [136/683] Converting Dragonfly_Threat_Against_Western_Energy_Suppliers.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Dragonfly_Threat_Against_Western_Energy_Suppliers.txt
# [136/683] Successfully converted Dragonfly_Threat_Against_Western_Energy_Suppliers.pdf
# [137/683] Converting EB-YetiJuly2014-Public.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\EB-YetiJuly2014-Public.txt
# [137/683] Successfully converted EB-YetiJuly2014-Public.pdf
# [138/683] Converting El_Machete.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\El_Machete.txt
# [138/683] Successfully converted El_Machete.pdf
# [139/683] Converting EvilBunny_Suspect4_v1.0.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\EvilBunny_Suspect4_v1.0.txt
# [139/683] Successfully converted EvilBunny_Suspect4_v1.0.pdf
# [140/683] Converting fireeye-operation-quantum-entanglement.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\fireeye-operation-quantum-entanglement.txt
# [140/683] Successfully converted fireeye-operation-quantum-entanglement.pdf
# [141/683] Converting fireeye-operation-saffron-rose.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\fireeye-operation-saffron-rose.txt
# [141/683] Successfully converted fireeye-operation-saffron-rose.pdf
# [142/683] Converting fireeye-sidewinder-targeted-attack.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\fireeye-sidewinder-targeted-attack.txt
# [142/683] Successfully converted fireeye-sidewinder-targeted-attack.pdf
# [143/683] Converting FTA 1001 FINAL 1.15.14.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\FTA 1001 FINAL 1.15.14.txt
# [143/683] Successfully converted FTA 1001 FINAL 1.15.14.pdf
# [144/683] Converting FTA 1011 Follow UP.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\FTA 1011 Follow UP.txt
# [144/683] Successfully converted FTA 1011 Follow UP.pdf
# [145/683] Converting FTA 1012 STTEAM Final.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\FTA 1012 STTEAM Final.txt
# [145/683] Successfully converted FTA 1012 STTEAM Final.pdf
# [146/683] Converting FTA_1013_RAT_in_a_jar.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\FTA_1013_RAT_in_a_jar.txt
# [146/683] Successfully converted FTA_1013_RAT_in_a_jar.pdf
# [147/683] Converting FTA_1014_Bots_Machines_and_the_Matrix.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\FTA_1014_Bots_Machines_and_the_Matrix.txt
# [147/683] Successfully converted FTA_1014_Bots_Machines_and_the_Matrix.pdf
# [148/683] Converting GDATA_TooHash_CaseStudy_102014_EN_v1.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\GDATA_TooHash_CaseStudy_102014_EN_v1.txt
# [148/683] Successfully converted GDATA_TooHash_CaseStudy_102014_EN_v1.pdf
# [149/683] Converting GData_Uroburos_RedPaper_EN_v1.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\GData_Uroburos_RedPaper_EN_v1.txt
# [149/683] Successfully converted GData_Uroburos_RedPaper_EN_v1.pdf
# [150/683] Converting Gholee_Protective_Edge_themed_spear_phishing_campaign.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Gholee_Protective_Edge_themed_spear_phishing_campaign.txt
# [150/683] Successfully converted Gholee_Protective_Edge_themed_spear_phishing_campaign.pdf
# [151/683] Converting Group72_Opening_ZxShell.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Group72_Opening_ZxShell.txt
# [151/683] Successfully converted Group72_Opening_ZxShell.pdf
# [152/683] Converting Group_72.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Group_72.txt
# [152/683] Successfully converted Group_72.pdf
# [153/683] Converting h12756-wp-shell-crew.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\h12756-wp-shell-crew.txt
# [153/683] Successfully converted h12756-wp-shell-crew.pdf
# [154/683] Converting Hikit_Analysis-Final.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Hikit_Analysis-Final.txt
# [154/683] Successfully converted Hikit_Analysis-Final.pdf
# [155/683] Converting HPSR SecurityBriefing_Episode16_NorthKorea.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\HPSR SecurityBriefing_Episode16_NorthKorea.txt
# [155/683] Successfully converted HPSR SecurityBriefing_Episode16_NorthKorea.pdf
# [156/683] Converting ICS_Havex_backdoors.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\ICS_Havex_backdoors.txt
# [156/683] Successfully converted ICS_Havex_backdoors.pdf
# [157/683] Converting Kaspersky_Darkhotel_kl_07.11_1.1(11-10-2014).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Kaspersky_Darkhotel_kl_07.11_1.1(11-10-2014).txt
# [157/683] Successfully converted Kaspersky_Darkhotel_kl_07.11_1.1(11-10-2014).pdf
# [158/683] Converting Kaspersky_Lab_crouching_yeti_appendixes_eng_final.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Kaspersky_Lab_crouching_yeti_appendixes_eng_final.txt
# [158/683] Successfully converted Kaspersky_Lab_crouching_yeti_appendixes_eng_final.pdf
# [159/683] Converting Kaspersky_Lab_whitepaper_Regin_platform_eng.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Kaspersky_Lab_whitepaper_Regin_platform_eng.txt
# [159/683] Successfully converted Kaspersky_Lab_whitepaper_Regin_platform_eng.pdf
# [160/683] Converting KL_Epic_Turla_Technical_Appendix_20140806.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\KL_Epic_Turla_Technical_Appendix_20140806.txt
# [160/683] Successfully converted KL_Epic_Turla_Technical_Appendix_20140806.pdf
# [161/683] Converting KL_report_syrian_malware.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\KL_report_syrian_malware.txt
# [161/683] Successfully converted KL_report_syrian_malware.pdf
# [162/683] Converting korea_power_plant_wiper.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\korea_power_plant_wiper.txt
# [162/683] Successfully converted korea_power_plant_wiper.pdf
# [163/683] Converting Korplug_Afghanistan_Tajikistan.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Korplug_Afghanistan_Tajikistan.txt
# [163/683] Successfully converted Korplug_Afghanistan_Tajikistan.pdf
# [164/683] Converting LeoUncia_OrcaRat.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\LeoUncia_OrcaRat.txt
# [164/683] Successfully converted LeoUncia_OrcaRat.pdf
# [165/683] Converting Micro-Targeted-Malvertising-WP-10-27-14-1.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Micro-Targeted-Malvertising-WP-10-27-14-1.txt
# [165/683] Successfully converted Micro-Targeted-Malvertising-WP-10-27-14-1.pdf
# [166/683] Converting Miniduke_twitter.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Miniduke_twitter.txt
# [166/683] Successfully converted Miniduke_twitter.pdf
# [167/683] Converting Modified_Binaries_Tor.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Modified_Binaries_Tor.txt
# [167/683] Successfully converted Modified_Binaries_Tor.pdf
# [168/683] Converting NetTraveler_Makeover_10th_Birthday.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\NetTraveler_Makeover_10th_Birthday.txt
# [168/683] Successfully converted NetTraveler_Makeover_10th_Birthday.pdf
# [169/683] Converting Novetta_Operation-SMN(10-24-2014).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Novetta_Operation-SMN(10-24-2014).txt
# [169/683] Successfully converted Novetta_Operation-SMN(10-24-2014).pdf
# [170/683] Converting OnionDuke_Tor.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\OnionDuke_Tor.txt
# [170/683] Successfully converted OnionDuke_Tor.pdf
# [171/683] Converting operation-poisoned-helmand.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\operation-poisoned-helmand.txt
# [171/683] Successfully converted operation-poisoned-helmand.pdf
# [172/683] Converting OperationCleaver_The_Notepad_Files.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\OperationCleaver_The_Notepad_Files.txt
# [172/683] Successfully converted OperationCleaver_The_Notepad_Files.pdf
# [173/683] Converting OperationDoubleTap.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\OperationDoubleTap.txt
# [173/683] Successfully converted OperationDoubleTap.pdf
# [174/683] Converting Operation_CloudyOmega_Ichitaro.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Operation_CloudyOmega_Ichitaro.txt
# [174/683] Successfully converted Operation_CloudyOmega_Ichitaro.pdf
# [175/683] Converting Operation_GreedyWonk.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Operation_GreedyWonk.txt
# [175/683] Successfully converted Operation_GreedyWonk.pdf
# [176/683] Converting Operation_Poisoned_Handover.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\
pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\tactical-intelligence-bulletin---sofacy-phishing-.txt
# [198/683] Successfully converted tactical-intelligence-bulletin---sofacy-phishing-.pdf
# [199/683] Converting targeted_attacks_against_the_energy_sector.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\targeted_attacks_against_the_energy_sector.txt
# [199/683] Successfully converted targeted_attacks_against_the_energy_sector.pdf
# [200/683] Converting Targeting_Syrian_ISIS_Critics.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Targeting_Syrian_ISIS_Critics.txt
# [200/683] Successfully converted Targeting_Syrian_ISIS_Critics.pdf
# [201/683] Converting th3bug_Watering_Hole_PoisonIvy.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\th3bug_Watering_Hole_PoisonIvy.txt
# [201/683] Successfully converted th3bug_Watering_Hole_PoisonIvy.pdf
# [202/683] Converting The_Monju_Incident.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\The_Monju_Incident.txt
# [202/683] Successfully converted The_Monju_Incident.pdf
# [203/683] Converting The_Siesta_Campaign.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\The_Siesta_Campaign.txt
# [203/683] Successfully converted The_Siesta_Campaign.pdf
# [204/683] Converting The_Uroburos_case.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\The_Uroburos_case.txt
# [204/683] Successfully converted The_Uroburos_case.pdf
# [205/683] Converting ThreatConnect_Operation_Arachnophobia_Report.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\ThreatConnect_Operation_Arachnophobia_Report.txt
# [205/683] Successfully converted ThreatConnect_Operation_Arachnophobia_Report.pdf
# [206/683] Converting TrapX_ZOMBIE_Report_Final.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\TrapX_ZOMBIE_Report_Final.txt
# [206/683] Successfully converted TrapX_ZOMBIE_Report_Final.pdf
# [207/683] Converting Turla_2_Penquin.pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2014\Turla_2_Penquin.txt
# [207/683] Successfully converted Turla_2_Penquin.pdf
# ...
# [635/683] Successfully converted Symantec_Ukraine-Disk-wiping-Russian-Invasion(02-24-2022).pdf
# [636/683] Converting Telsy_BabaDeda-LorecCPL-Outsteel-Ukraine(02-16-2022).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2022\Telsy_BabaDeda-LorecCPL-Outsteel-Ukraine(02-16-2022).txt
# [636/683] Successfully converted Telsy_BabaDeda-LorecCPL-Outsteel-Ukraine(02-16-2022).pdf
# [637/683] Converting TheDFIRReport_APT35-Automates-Initial-Access-Using-ProxyShell(03-21-2022).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2022\TheDFIRReport_APT35-Automates-Initial-Access-Using-ProxyShell(03-21-2022).txt
# [637/683] Successfully converted TheDFIRReport_APT35-Automates-Initial-Access-Using-ProxyShell(03-21-2022).pdf
# [638/683] Converting Trellix_PrimeMinisters-Details-Espionage-Campaign(01-25-2022).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2022\Trellix_PrimeMinisters-Details-Espionage-Campaign(01-25-2022).txt
# [638/683] Successfully converted Trellix_PrimeMinisters-Details-Espionage-Campaign(01-25-2022).pdf
# [639/683] Converting Zscaler-Naver-ending-game-Lazarus-APT(04-26-2022).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2022\Zscaler-Naver-ending-game-Lazarus-APT(04-26-2022).txt
# [639/683] Successfully converted Zscaler-Naver-ending-game-Lazarus-APT(04-26-2022).pdf
# [640/683] Converting Zscaler_Molerats-APT-targeting-Middle-East(01-20-2022).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2022\Zscaler_Molerats-APT-targeting-Middle-East(01-20-2022).txt
# [640/683] Successfully converted Zscaler_Molerats-APT-targeting-Middle-East(01-20-2022).pdf
# [641/683] Converting 360_APT-C-56-TransparentTribe-camouflage-campaign(02-13-2023).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2023
2023).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2023\ESET_WinorDLL64-Lazarus-arsenal(02-23-2023).txt
# [663/683] Successfully converted ESET_WinorDLL64-Lazarus-arsenal(02-23-2023).pdf
# [664/683] Converting Group-ib_DarkPink(01-11-2023).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2023\Group-ib_DarkPink(01-11-2023).txt
# [664/683] Successfully converted Group-ib_DarkPink(01-11-2023).pdf
# [665/683] Converting ITG05_operations_leverage_Israel-Hamas_conflict_lures_to_deliver_Headlace_malware(12-08-2023).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2023\ITG05_operations_leverage_Israel-Hamas_conflict_lures_to_deliver_Headlace_malware(12-08-2023).txt
# [665/683] Successfully converted ITG05_operations_leverage_Israel-Hamas_conflict_lures_to_deliver_Headlace_malware(12-08-2023).pdf
# [666/683] Converting Kaspersky_cascade-of-compromise-unveiling-Lazarus-new-campaign(10-27-2023).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2023\Kaspersky_cascade-of-compromise-unveiling-Lazarus-new-campaign(10-27-2023).txt
# [666/683] Successfully converted Kaspersky_cascade-of-compromise-unveiling-Lazarus-new-campaign(10-27-2023).pdf
# [667/683] Converting Kaspersky_HrServ-webshell-in-APT-attack(11-22-2023).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2023\Kaspersky_HrServ-webshell-in-APT-attack(11-22-2023).txt
# [667/683] Successfully converted Kaspersky_HrServ-webshell-in-APT-attack(11-22-2023).pdf
# [668/683] Converting Kaspersky_Modern-Asian-APT-groups-TTPs_report_eng(11-09-2023).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2023\Kaspersky_Modern-Asian-APT-groups-TTPs_report_eng(11-09-2023).txt
# [668/683] Successfully converted Kaspersky_Modern-Asian-APT-groups-TTPs_report_eng(11-09-2023).pdf
# [669/683] Converting Kaspersky_OperationTriangulation-TheLastMystery(12-27-2023).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2023\Kaspersky_OperationTriangulation-TheLastMystery(12-27-2023).txt
# [669/683] Successfully converted Kaspersky_OperationTriangulation-TheLastMystery(12-27-2023).pdf
# [670/683] Converting Mandiant_Fortinet-Zero-Day-Suspected-Chinese-Operation(03-16-2023).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2023\Mandiant_Fortinet-Zero-Day-Suspected-Chinese-Operation(03-16-2023).txt
# [670/683] Successfully converted Mandiant_Fortinet-Zero-Day-Suspected-Chinese-Operation(03-16-2023).pdf
# [671/683] Converting Mandiant_LIGHTSHOW-1-North-Koreas-UNC2970(03-09-2023).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2023\Mandiant_LIGHTSHOW-1-North-Koreas-UNC2970(03-09-2023).txt
# [671/683] Successfully converted Mandiant_LIGHTSHOW-1-North-Koreas-UNC2970(03-09-2023).pdf
# [672/683] Converting Mandiant_LIGHTSHOW-2-LIGHTSHIFT-and-LIGHTSHOW(03-09-2023).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2023\Mandiant_LIGHTSHOW-2-LIGHTSHIFT-and-LIGHTSHOW(03-09-2023).txt
# [672/683] Successfully converted Mandiant_LIGHTSHOW-2-LIGHTSHIFT-and-LIGHTSHOW(03-09-2023).pdf
# [673/683] Converting Netskope_Nim-based-Campaign-Word-Docs-Impersonate-Nepali-Gov(12-20-2023).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2023\Netskope_Nim-based-Campaign-Word-Docs-Impersonate-Nepali-Gov(12-20-2023).txt
# [673/683] Successfully converted Netskope_Nim-based-Campaign-Word-Docs-Impersonate-Nepali-Gov(12-20-2023).pdf
# [674/683] Converting PaloAlto_NewToolSet-Organizations-in-Middle-East-Africa-and-US(12-01-2023).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2023\PaloAlto_NewToolSet-Organizations-in-Middle-East-Africa-and-US(12-01-2023).txt
# [674/683] Successfully converted PaloAlto_NewToolSet-Organizations-in-Middle-East-Africa-and-US(12-01-2023).pdf
# [675/683] Converting Proofpoint_Russia-Aligned-TA499-Beleaguers-Targets-Video-Call-Requests(03-07-2023).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2023\Proofpoint_Russia-Aligned-TA499-Beleaguers-Targets-Video-Call-Requests(03-07-2023).txt
# [675/683] Successfully converted Proofpoint_Russia-Aligned-TA499-Beleaguers-Targets-Video-Call-Requests(03-07-2023).pdf
# [676/683] Converting Sentinelone_GazaCybergang -UnifiedFront-Targeting-Opposition(12-14-2023).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2023\Sentinelone_GazaCybergang -UnifiedFront-Targeting-Opposition(12-14-2023).txt
# [676/683] Successfully converted Sentinelone_GazaCybergang -UnifiedFront-Targeting-Opposition(12-14-2023).pdf
# [677/683] Converting Symantec_Blackfly_Materials_Technology(02-28-2023).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2023\Symantec_Blackfly_Materials_Technology(02-28-2023).txt
# [677/683] Successfully converted Symantec_Blackfly_Materials_Technology(02-28-2023).pdf
# [678/683] Converting Symantec_Graphiron-Russian-Malware-Deployed-Against-Ukraine(02-08-2023).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2023\Symantec_Graphiron-Russian-Malware-Deployed-Against-Ukraine(02-08-2023).txt
# [678/683] Successfully converted Symantec_Graphiron-Russian-Malware-Deployed-Against-Ukraine(02-08-2023).pdf
# [679/683] Converting Symantec_Hydrochasma-UnknownGroup-Targets-Medical-Shipping-Asia(02-22-2023).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2023\Symantec_Hydrochasma-UnknownGroup-Targets-Medical-Shipping-Asia(02-22-2023).txt
# [679/683] Successfully converted Symantec_Hydrochasma-UnknownGroup-Targets-Medical-Shipping-Asia(02-22-2023).pdf
# [680/683] Converting Symantec_Seedworm-Iranian-Hackers-Target-Telecoms-Orgs-North-East-Africa(12-19-2023).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2023\Symantec_Seedworm-Iranian-Hackers-Target-Telecoms-Orgs-North-East-Africa(12-19-2023).txt
# [680/683] Successfully converted Symantec_Seedworm-Iranian-Hackers-Target-Telecoms-Orgs-North-East-Africa(12-19-2023).pdf
# [681/683] Converting Trendmicro_IronTigers-SysUpdate-Adds-Linux-Targeting(03-01-2023).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2023\Trendmicro_IronTigers-SysUpdate-Adds-Linux-Targeting(03-01-2023).txt
# [681/683] Successfully converted Trendmicro_IronTigers-SysUpdate-Adds-Linux-Targeting(03-01-2023).pdf
# [682/683] Converting Trendmicro_New-APT34-Malware-Targets-MiddleEast(02-02-2023).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2023\Trendmicro_New-APT34-Malware-Targets-MiddleEast(02-02-2023).txt
# [682/683] Successfully converted Trendmicro_New-APT34-Malware-Targets-MiddleEast(02-02-2023).pdf
# [683/683] Converting Cyble_OperationShadowCat-Targeting-Indian-Political-Observers(07-24-2024).pdf to e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf\2024\Cyble_OperationShadowCat-Targeting-Indian-Political-Observers(07-24-2024).txt
# [683/683] Successfully converted Cyble_OperationShadowCat-Targeting-Indian-Political-Observers(07-24-2024).pdf
#
# Conversion Summary:
# Total PDF files: 683
# Successfully converted: 683
# Failed conversions: 0
#
# Text files have been saved to: e:\CExperiment\ThreatRAG\kg\data_spider\aptnote_text\pymupdf
